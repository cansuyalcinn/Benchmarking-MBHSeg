# %%
import utils.metrics
import nibabel as nib
import numpy as np

score_map_path = '/media/cansu/DiskSpace/Cansu/Benchmarking-MBHSeg/model/MBHSeg_Vnet_FullySup_fold0/vnet/val_images/sample_0_pred.nii.gz'
score_map = nib.load(score_map_path).get_fdata()
label_path = '/media/cansu/DiskSpace/Cansu/Benchmarking-MBHSeg/model/MBHSeg_Vnet_FullySup_fold0/vnet/val_images/sample_0_gt.nii.gz'
label = nib.load(label_path).get_fdata().astype(np.uint8)
num_classes = 6

per_class_dice, _ = utils.metrics.compute_per_class_dice_numpy(
    score_map,
    label, 
    num_classes=num_classes
)

print("Per class dice:", per_class_dice)
# Out:
# Per class dice: [None, None, 1.7653808806134028e-10, 6.854009548635988e-09, 1.1961722344955475e-08, 5.568858937701811e-10]
