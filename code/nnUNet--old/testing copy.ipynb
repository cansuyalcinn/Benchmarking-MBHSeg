# %%
# !export nnUNet_raw=/home/cansu/SSLCAT/SSLesion/code/nnUNet/data/nnUNet_raw
# !export nnUNet_preprocessed=/home/cansu/SSLCAT/SSLesion/code/nnUNet/data/nnUNet_preprocessed
# !export nnUNet_results=/home/cansu/SSLCAT/SSLesion/code/nnUNet/data/nnUNet_results
# !echo ${nnUNet_raw}

import torch
from nnunetv2.inference.predict_from_raw_data import nnUNetPredictor

# Set these paths accordingly
model_name = "nnUNetTrainer__nnUNetPlans__3d_fullres__perc1.0"  # Change this to your model name
datasetname = "Dataset105_Brats19"  # Change this to your dataset name
best_or_final = "final"  # or "best"
input_folder = f"/home/cansu/SSLCAT/SSLesion/code/nnUNet/data/nnUNet_raw/{datasetname}/imagesTs" 
output_folder = f"/home/cansu/SSLCAT/SSLesion/code/nnUNet/data/nnUNet_results/{datasetname}/{model_name}/results_{best_or_final}" 
# create the output folder if it doesn't exist
import os
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

checkpoint_path = f"/home/cansu/SSLCAT/SSLesion/code/nnUNet/data/nnUNet_results/{datasetname}/{model_name}"
checkpoint_file = f"checkpoint_{best_or_final}.pth"

# Optional
folds = (0,) 

# INITIALIZEE CUDA 

os.environ["CUDA_VISIBLE_DEVICES"] = "3" 

predictor = nnUNetPredictor(
    tile_step_size=0.5,
    use_gaussian=True,
    use_mirroring=True,
    perform_everything_on_device=True,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    verbose=True,
    verbose_preprocessing=False,
    allow_tqdm=True
)

predictor.initialize_from_trained_model_folder(
    model_training_output_dir=checkpoint_path,
    use_folds=folds,
    checkpoint_name=checkpoint_file, 
    model_name = model_name,
)

# Use the simpler sequential mode to avoid multiprocessing issues in notebooks
predictor.predict_from_files_sequential(
    list_of_lists_or_source_folder=input_folder,
    output_folder_or_list_of_truncated_output_files=output_folder,
    save_probabilities=False,
    overwrite=True
)
# Out:
# There are 60 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 60 cases that I would like to predict
# None
# old shape: (138, 173, 143), new_shape: [138 173 143], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 173, 143])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 173, 143]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 38, 77], [0, 47]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.76it/s]
# Prediction done
# None
# old shape: (140, 173, 130), new_shape: [140 173 130], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 140, 173, 130])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([140, 173, 130]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 44], [0, 38, 77], [0, 34]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.02it/s]
# Prediction done
# None
# old shape: (137, 159, 136), new_shape: [137 159 136], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 137, 159, 136])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([137, 159, 136]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 41], [0, 32, 63], [0, 40]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:02<00:00,  5.54it/s]
# Prediction done
# None
# old shape: (143, 181, 134), new_shape: [143 181 134], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 181, 134])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 181, 134]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 42, 85], [0, 38]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.80it/s]
# Prediction done
# None
# old shape: (145, 169, 125), new_shape: [145 169 125], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 145, 169, 125])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([145, 169, 125]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 24, 49], [0, 36, 73], [0, 29]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.51it/s]
# Prediction done
# None
# old shape: (141, 174, 141), new_shape: [141 174 141], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 141, 174, 141])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([141, 174, 141]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 45], [0, 39, 78], [0, 45]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.71it/s]
# Prediction done
# None
# old shape: (138, 152, 132), new_shape: [138 152 132], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 152, 132])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 152, 132]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 28, 56], [0, 36]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (130, 165, 140), new_shape: [130 165 140], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 130, 165, 140])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([130, 165, 140]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 34], [0, 34, 69], [0, 44]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.69it/s]
# Prediction done
# None
# old shape: (143, 178, 138), new_shape: [143 178 138], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 178, 138])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 178, 138]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 41, 82], [0, 42]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (129, 175, 128), new_shape: [129 175 128], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 129, 175, 128])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([129, 175, 128]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 33], [0, 40, 79], [0, 32]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.71it/s]
# Prediction done
# None
# old shape: (137, 172, 133), new_shape: [137 172 133], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 137, 172, 133])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([137, 172, 133]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 41], [0, 38, 76], [0, 37]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (143, 158, 143), new_shape: [143 158 143], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 158, 143])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 158, 143]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 31, 62], [0, 47]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (144, 163, 133), new_shape: [144 163 133], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 144, 163, 133])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([144, 163, 133]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 48], [0, 34, 67], [0, 37]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (140, 181, 132), new_shape: [140 181 132], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 140, 181, 132])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([140, 181, 132]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 44], [0, 42, 85], [0, 36]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.69it/s]
# Prediction done
# None
# old shape: (136, 163, 135), new_shape: [136 163 135], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 136, 163, 135])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([136, 163, 135]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 40], [0, 34, 67], [0, 39]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.68it/s]
# Prediction done
# None
# old shape: (139, 165, 141), new_shape: [139 165 141], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 165, 141])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 165, 141]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 34, 69], [0, 45]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.71it/s]
# Prediction done
# None
# old shape: (141, 176, 138), new_shape: [141 176 138], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 141, 176, 138])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([141, 176, 138]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 45], [0, 40, 80], [0, 42]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.76it/s]
# Prediction done
# None
# old shape: (144, 157, 135), new_shape: [144 157 135], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 144, 157, 135])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([144, 157, 135]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 48], [0, 30, 61], [0, 39]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.72it/s]
# Prediction done
# None
# old shape: (138, 169, 141), new_shape: [138 169 141], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 169, 141])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 169, 141]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 36, 73], [0, 45]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (143, 172, 145), new_shape: [143 172 145], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 172, 145])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([143, 172, 145]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 38, 76], [0, 24, 49]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.48it/s]
# Prediction done
# None
# old shape: (134, 162, 135), new_shape: [134 162 135], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 134, 162, 135])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([134, 162, 135]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 38], [0, 33, 66], [0, 39]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.71it/s]
# Prediction done
# None
# old shape: (139, 163, 128), new_shape: [139 163 128], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 163, 128])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 163, 128]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 34, 67], [0, 32]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.70it/s]
# Prediction done
# None
# old shape: (143, 175, 134), new_shape: [143 175 134], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 175, 134])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 175, 134]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 40, 79], [0, 38]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.43it/s]
# Prediction done
# None
# old shape: (134, 169, 140), new_shape: [134 169 140], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 134, 169, 140])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([134, 169, 140]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 38], [0, 36, 73], [0, 44]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:05<00:00,  2.32it/s]
# Prediction done
# None
# old shape: (141, 176, 141), new_shape: [141 176 141], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 141, 176, 141])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([141, 176, 141]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 45], [0, 40, 80], [0, 45]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.72it/s]
# Prediction done
# None
# old shape: (143, 173, 136), new_shape: [143 173 136], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 173, 136])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 173, 136]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 38, 77], [0, 40]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.76it/s]
# Prediction done
# None
# old shape: (139, 176, 138), new_shape: [139 176 138], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 176, 138])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 176, 138]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 40, 80], [0, 42]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:05<00:00,  2.34it/s]
# Prediction done
# None
# old shape: (139, 161, 137), new_shape: [139 161 137], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 161, 137])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 161, 137]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 32, 65], [0, 41]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.51it/s]
# Prediction done
# None
# old shape: (143, 168, 137), new_shape: [143 168 137], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 168, 137])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 168, 137]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 36, 72], [0, 41]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.60it/s]
# Prediction done
# None
# old shape: (131, 169, 139), new_shape: [131 169 139], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 131, 169, 139])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([131, 169, 139]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 35], [0, 36, 73], [0, 43]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:05<00:00,  2.33it/s]
# Prediction done
# None
# old shape: (138, 175, 145), new_shape: [138 175 145], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 175, 145])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([138, 175, 145]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 40, 79], [0, 24, 49]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.55it/s]
# Prediction done
# None
# old shape: (142, 185, 132), new_shape: [142 185 132], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 142, 185, 132])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([142, 185, 132]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 46], [0, 44, 89], [0, 36]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:02<00:00,  4.73it/s]
# Prediction done
# None
# old shape: (141, 165, 143), new_shape: [141 165 143], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 141, 165, 143])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([141, 165, 143]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 45], [0, 34, 69], [0, 47]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.55it/s]
# Prediction done
# None
# old shape: (138, 160, 133), new_shape: [138 160 133], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 160, 133])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 160, 133]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 32, 64], [0, 37]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:05<00:00,  2.32it/s]
# Prediction done
# None
# old shape: (141, 168, 126), new_shape: [141 168 126], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 141, 168, 126])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([141, 168, 126]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 45], [0, 36, 72], [0, 30]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.40it/s]
# Prediction done
# None
# old shape: (136, 165, 146), new_shape: [136 165 146], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 136, 165, 146])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([136, 165, 146]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 40], [0, 34, 69], [0, 25, 50]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.39it/s]
# Prediction done
# None
# old shape: (139, 164, 136), new_shape: [139 164 136], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 164, 136])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 164, 136]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 34, 68], [0, 40]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.60it/s]
# Prediction done
# None
# old shape: (149, 176, 143), new_shape: [149 176 143], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 149, 176, 143])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([149, 176, 143]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 26, 53], [0, 40, 80], [0, 47]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.48it/s]
# Prediction done
# None
# old shape: (146, 176, 148), new_shape: [146 176 148], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 146, 176, 148])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 27, image size is torch.Size([146, 176, 148]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 25, 50], [0, 40, 80], [0, 26, 52]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 27/27 [00:11<00:00,  2.40it/s]
# Prediction done
# None
# old shape: (137, 172, 127), new_shape: [137 172 127], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 137, 172, 127])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([137, 172, 127]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 41], [0, 38, 76], [0, 31]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.58it/s]
# Prediction done
# None
# old shape: (140, 161, 146), new_shape: [140 161 146], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 140, 161, 146])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([140, 161, 146]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 44], [0, 32, 65], [0, 25, 50]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.56it/s]
# Prediction done
# None
# old shape: (134, 159, 133), new_shape: [134 159 133], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 134, 159, 133])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([134, 159, 133]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 38], [0, 32, 63], [0, 37]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:05<00:00,  2.32it/s]
# Prediction done
# None
# old shape: (141, 165, 136), new_shape: [141 165 136], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 141, 165, 136])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([141, 165, 136]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 45], [0, 34, 69], [0, 40]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.61it/s]
# Prediction done
# None
# old shape: (139, 165, 147), new_shape: [139 165 147], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 165, 147])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([139, 165, 147]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 34, 69], [0, 26, 51]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:07<00:00,  2.55it/s]
# Prediction done
# None
# old shape: (134, 173, 143), new_shape: [134 173 143], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 134, 173, 143])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([134, 173, 143]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 38], [0, 38, 77], [0, 47]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:04<00:00,  2.64it/s]
# Prediction done
# None
# old shape: (117, 145, 127), new_shape: [117 145 127], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 117, 145, 127])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([117, 145, 127]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 21], [0, 24, 49], [0, 31]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.57it/s]
# Prediction done
# None
# old shape: (138, 161, 133), new_shape: [138 161 133], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 161, 133])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 161, 133]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 32, 65], [0, 37]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.56it/s]
# Prediction done
# None
# old shape: (139, 173, 146), new_shape: [139 173 146], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 173, 146])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([139, 173, 146]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 38, 77], [0, 25, 50]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:05<00:00,  3.50it/s]
# Prediction done
# None
# old shape: (138, 171, 135), new_shape: [138 171 135], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 171, 135])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 171, 135]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 38, 75], [0, 39]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.56it/s]
# Prediction done
# None
# old shape: (145, 181, 138), new_shape: [145 181 138], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 145, 181, 138])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([145, 181, 138]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 24, 49], [0, 42, 85], [0, 42]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:05<00:00,  3.52it/s]
# Prediction done
# None
# old shape: (140, 175, 138), new_shape: [140 175 138], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 140, 175, 138])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([140, 175, 138]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 44], [0, 40, 79], [0, 42]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.55it/s]
# Prediction done
# None
# old shape: (146, 160, 127), new_shape: [146 160 127], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 146, 160, 127])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([146, 160, 127]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 25, 50], [0, 32, 64], [0, 31]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:05<00:00,  3.52it/s]
# Prediction done
# None
# old shape: (145, 137, 145), new_shape: [145 137 145], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 145, 137, 145])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([145, 137, 145]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 24, 49], [0, 41], [0, 24, 49]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:05<00:00,  3.52it/s]
# Prediction done
# None
# old shape: (139, 164, 132), new_shape: [139 164 132], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 164, 132])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 164, 132]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 34, 68], [0, 36]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.56it/s]
# Prediction done
# None
# old shape: (138, 159, 142), new_shape: [138 159 142], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 138, 159, 142])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([138, 159, 142]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 42], [0, 32, 63], [0, 46]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.56it/s]
# Prediction done
# None
# old shape: (134, 160, 130), new_shape: [134 160 130], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 134, 160, 130])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([134, 160, 130]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 38], [0, 32, 64], [0, 34]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:03<00:00,  3.54it/s]
# Prediction done
# None
# old shape: (130, 167, 148), new_shape: [130 167 148], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 130, 167, 148])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 18, image size is torch.Size([130, 167, 148]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 34], [0, 36, 71], [0, 26, 52]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 18/18 [00:05<00:00,  3.46it/s]
# Prediction done
# None
# old shape: (143, 174, 137), new_shape: [143 174 137], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 143, 174, 137])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([143, 174, 137]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 47], [0, 39, 78], [0, 41]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:01<00:00,  7.55it/s]
# Prediction done
# None
# old shape: (139, 171, 134), new_shape: [139 171 134], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 171, 134])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 171, 134]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 38, 75], [0, 38]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:01<00:00,  7.57it/s]
# Prediction done
# None
# old shape: (139, 158, 137), new_shape: [139 158 137], old_spacing: [np.float64(1.0), np.float64(1.0), np.float64(1.0)], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fdafcc8ce00>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# perform_everything_on_device: True
# Input shape: torch.Size([1, 139, 158, 137])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 12, image size is torch.Size([139, 158, 137]), tile_size [96, 96, 96], tile_step_size 0.5
# steps:
# [[0, 43], [0, 31, 62], [0, 41]]
# move image to device cuda
# preallocating results arrays on device cuda
# 100%|██████████| 12/12 [00:01<00:00,  7.56it/s]
# Prediction done
# []
