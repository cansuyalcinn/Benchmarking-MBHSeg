# %% [markdown]
# Invetsigating to the dataset splits for mbhseg24 and 25

# %%
database_path1 = '/media/cansu/DiskSpace/Cansu/Benchmarking-MBHSeg/data/splits/mbhseg24'
database_path2 = '/media/cansu/DiskSpace/Cansu/Benchmarking-MBHSeg/data/splits/mbhseg25'

for i in range(1, 6):
    train_file1 = f'{database_path1}/fold_{i}_train.txt'
    val_file1 = f'{database_path1}/fold_{i}_val.txt'

    train_file2 = f'{database_path2}/fold_{i}_train.txt'
    val_file2 = f'{database_path2}/fold_{i}_val.txt'


    with open(train_file1, 'r') as f1, open(train_file2, 'r') as f2:
        train_lines1 = f1.readlines()
        train_lines2 = f2.readlines()

    with open(val_file1, 'r') as f1, open(val_file2, 'r') as f2:
        val_lines1 = f1.readlines()
        val_lines2 = f2.readlines()


    print('number of training in mbhseg24 fold', i, ':', len(train_lines1))
    print('number of training in mbhseg25 fold', i, ':', len(train_lines2))
    print('number of validation in mbhseg24 fold', i, ':', len(val_lines1))
    print('number of validation in mbhseg25 fold', i, ':', len(val_lines2))

    break
